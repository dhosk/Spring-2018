# %% [markdown]
# # Data collection and manipulation
#
# - Common shell commands for interactions outside programming environment
#     - Downloading files from a URL
#     - Inspect, search, and replace text in files
#     - Chaining commands together for sequential processing
# - Shell and IPython (Jupyter notebook)
#     - Reading shell command output into python variable
#     - Passing python string back to shell command
#     - IRS zip code data example: parsing website, extracting URL, and downloading all files
# - Accessing NBA data
#     - Understanding GET URL structure
#     - JSON data format
#     - Reading JSON data into python
#     - Creating Pandas data frame
#
# ## Shell commands
#
# ### Useful Shell Commands for Text Files
#
# - `cat`: prints content of a file
# - `head`: prints first few lines of a file
# - `sed`: (stream editor) changes texts
# - `paste`: pasts text files side-by-side
# - `cut`: processes columns in delimited text file
# - `find`: searches file system
# - `grep`: searches text given regular expression pattern
# - Many more!
#
# ### References to learn shell command line
#
# - [Software Carpentry Lessons](https://software-carpentry.org/lessons/)
# - [Unix Power Tools](https://ucsb-primo.hosted.exlibrisgroup.com/primo-explore/fulldisplay?docid=01UCSB_ALMA51295276690003776&context=L&vid=UCSB&search_scope=default_scope&tab=default_tab&lang=en_US)
#
# ### File download
#
# Sometimes URL of a csv file is directly visible (e.g., Github). In these cases, `wget` is simple but effective. Take https://github.com/fivethirtyeight/data for example. There are many csv files in this repository, and when you browse a file, you see a button named "raw".
#
# Take the candy ratings data: https://github.com/fivethirtyeight/data/tree/master/candy-power-ranking. Using `wget` it is easy to download the file to course jupyterhub.

# %%
# %%bash
# wget https://raw.githubusercontent.com/fivethirtyeight/data/master/candy-power-ranking/candy-data.csv
# Out:
# --2018-04-22 12:59:51--  https://raw.githubusercontent.com/fivethirtyeight/data/master/candy-power-ranking/candy-data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.24.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.24.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5205 (5.1K) [text/plain]
# Saving to: ‘candy-data.csv.2’
#
#      0K .....                                                 100% 7.85M=0.001s
#
# 2018-04-22 12:59:51 (7.85 MB/s) - ‘candy-data.csv.2’ saved [5205/5205]

# %% [markdown]
# ### Viewing file contents

# %%
# %%bash
# head candy-data.csv
# Out:
# competitorname,chocolate,fruity,caramel,peanutyalmondy,nougat,crispedricewafer,hard,bar,pluribus,sugarpercent,pricepercent,winpercent
# 100 Grand,1,0,1,0,0,1,0,1,0,.73199999,.86000001,66.971725
# 3 Musketeers,1,0,0,0,1,0,0,1,0,.60399997,.51099998,67.602936
# One dime,0,0,0,0,0,0,0,0,0,.011,.116,32.261086
# One quarter,0,0,0,0,0,0,0,0,0,.011,.51099998,46.116505
# Air Heads,0,1,0,0,0,0,0,0,0,.90600002,.51099998,52.341465
# Almond Joy,1,0,0,1,0,0,0,1,0,.465,.76700002,50.347546
# Baby Ruth,1,0,1,1,1,0,0,1,0,.60399997,.76700002,56.914547
# Boston Baked Beans,0,0,0,1,0,0,0,0,1,.31299999,.51099998,23.417824
# Candy Corn,0,0,0,0,0,0,0,0,1,.90600002,.32499999,38.010963

# %%
! head candy-data.csv ## also works
# Out:
# competitorname,chocolate,fruity,caramel,peanutyalmondy,nougat,crispedricewafer,hard,bar,pluribus,sugarpercent,pricepercent,winpercent
# 100 Grand,1,0,1,0,0,1,0,1,0,.73199999,.86000001,66.971725
# 3 Musketeers,1,0,0,0,1,0,0,1,0,.60399997,.51099998,67.602936
# One dime,0,0,0,0,0,0,0,0,0,.011,.116,32.261086
# One quarter,0,0,0,0,0,0,0,0,0,.011,.51099998,46.116505
# Air Heads,0,1,0,0,0,0,0,0,0,.90600002,.51099998,52.341465
# Almond Joy,1,0,0,1,0,0,0,1,0,.465,.76700002,50.347546
# Baby Ruth,1,0,1,1,1,0,0,1,0,.60399997,.76700002,56.914547
# Boston Baked Beans,0,0,0,1,0,0,0,0,1,.31299999,.51099998,23.417824
# Candy Corn,0,0,0,0,0,0,0,0,1,.90600002,.32499999,38.010963

# %%
! head -n 1 candy-data.csv  ## first line is the header
# Out:
# competitorname,chocolate,fruity,caramel,peanutyalmondy,nougat,crispedricewafer,hard,bar,pluribus,sugarpercent,pricepercent,winpercent

# %%
! wc -l candy-data.csv      ## counts lines in text file
# Out:
# 86 candy-data.csv

# %%
! cut -d',' -f1,3 candy-data.csv    ## prints columns of delimited text
# Out:
# competitorname,fruity
# 100 Grand,0
# 3 Musketeers,0
# One dime,0
# One quarter,0
# Air Heads,1
# Almond Joy,0
# Baby Ruth,0
# Boston Baked Beans,0
# Candy Corn,0
# Caramel Apple Pops,1
# Charleston Chew,0
# Chewey Lemonhead Fruit Mix,1
# Chiclets,1
# Dots,1
# Dum Dums,1
# Fruit Chews,1
# Fun Dip,1
# Gobstopper,1
# Haribo Gold Bears,1
# Haribo Happy Cola,0
# Haribo Sour Bears,1
# Haribo Twin Snakes,1
# HersheyÕs Kisses,0
# HersheyÕs Krackel,0
# HersheyÕs Milk Chocolate,0
# HersheyÕs Special Dark,0
# Jawbusters,1
# Junior Mints,0
# Kit Kat,0
# Laffy Taffy,1
# Lemonhead,1
# Lifesavers big ring gummies,1
# Peanut butter M&MÕs,0
# M&MÕs,0
# Mike & Ike,1
# Milk Duds,0
# Milky Way,0
# Milky Way Midnight,0
# Milky Way Simply Caramel,0
# Mounds,0
# Mr Good Bar,0
# Nerds,1
# Nestle Butterfinger,0
# Nestle Crunch,0
# Nik L Nip,1
# Now & Later,1
# Payday,0
# Peanut M&Ms,0
# Pixie Sticks,0
# Pop Rocks,1
# Red vines,1
# ReeseÕs Miniatures,0
# ReeseÕs Peanut Butter cup,0
# ReeseÕs pieces,0
# ReeseÕs stuffed with pieces,0
# Ring pop,1
# Rolo,0
# Root Beer Barrels,0
# Runts,1
# Sixlets,0
# Skittles original,1
# Skittles wildberry,1
# Nestle Smarties,0
# Smarties candy,1
# Snickers,0
# Snickers Crisper,0
# Sour Patch Kids,1
# Sour Patch Tricksters,1
# Starburst,1
# Strawberry bon bons,1
# Sugar Babies,0
# Sugar Daddy,0
# Super Bubble,1
# Swedish Fish,1
# Tootsie Pop,1
# Tootsie Roll Juniors,0
# Tootsie Roll Midgies,0
# Tootsie Roll Snack Bars,0
# Trolli Sour Bites,1
# Twix,0
# Twizzlers,1
# Warheads,1
# WelchÕs Fruit Snacks,1
# WertherÕs Original Caramel,0
# Whoppers,0

# %%
! grep 'Tootsie' candy-data.csv      ## finds lines with pattern (regular expression)
# Out:
# Tootsie Pop,1,1,0,0,0,0,1,0,0,.60399997,.32499999,48.982651
# Tootsie Roll Juniors,1,0,0,0,0,0,0,0,0,.31299999,.51099998,43.068897
# Tootsie Roll Midgies,1,0,0,0,0,0,0,0,1,.17399999,.011,45.736748
# Tootsie Roll Snack Bars,1,0,0,0,0,0,0,1,0,.465,.32499999,49.653503

# %% [markdown]
# ### Chaining commands togeter
#
# The power of command lines is unleashed when you chain commands together. You can achieve this by using "pipes".
# Many commands in the shell sends output to what is called "stdout" (essentially printing to screen). What enables pipes is to receive input from "stdin" (standard input).
#
# Hence, we can make commands such as the following

# %%
! head -n1 candy-data.csv
# Out:
# competitorname,chocolate,fruity,caramel,peanutyalmondy,nougat,crispedricewafer,hard,bar,pluribus,sugarpercent,pricepercent,winpercent

# %%
! head -n1 candy-data.csv | sed 's/,/\n/g'
# Out:
# competitorname
# chocolate
# fruity
# caramel
# peanutyalmondy
# nougat
# crispedricewafer
# hard
# bar
# pluribus
# sugarpercent
# pricepercent
# winpercent

# %%
! head -n1 candy-data.csv | sed 's/,/\n/g' | sed 's/chocolate/CHOCOLATE/g'
# Out:
# competitorname
# CHOCOLATE
# fruity
# caramel
# peanutyalmondy
# nougat
# crispedricewafer
# hard
# bar
# pluribus
# sugarpercent
# pricepercent
# winpercent

# %% [markdown]
# ### Text file search and manipulation
#
# Comands like `grep`, `sed` and `awk` enable on-the-fly text processing.

# %%
a = !wget -q -O - https://www.irs.gov/statistics/soi-tax-stats-individual-income-tax-statistics-zip-code-data-soi \
     | grep 'zipcode.zip' \
     | sed 's/<a data/\n<a data/g' \
#     | grep -Po '(?<=href=")[^"]*(?=")'
a
# Out:
# ['<p>',
#  '<a data-entity-substitution="pup_linkit_media" data-entity-type="media" data-entity-uuid="ea6aec5f-4467-4336-8614-7d4835d3d0e4" href="https://www.irs.gov/pub/irs-soi/1998zipcode.zip" title="1998zipcode.zip">1998</a>\xa0 ',
#  '<a data-entity-substitution="pup_linkit_media" data-entity-type="media" data-entity-uuid="5d7989e2-c9d1-4f4e-bc07-ed8554abad06" href="https://www.irs.gov/pub/irs-soi/2001zipcode.zip" title="2001zipcode.zip">2001</a>\xa0 ',
#  '<a data-entity-substitution="pup_linkit_media" data-entity-type="media" data-entity-uuid="7c05be6c-63a0-4b42-8645-35f2d7ed2890" href="https://www.irs.gov/pub/irs-soi/2002zipcode.zip" title="2002zipcode.zip">2002</a> \xa0',
#  '<a data-entity-substitution="pup_linkit_media" data-entity-type="media" data-entity-uuid="e8e8a62d-e3f9-4129-a8f7-039498adcd61" href="https://www.irs.gov/pub/irs-soi/2004zipcode.zip" title="2004zipcode.zip">2004</a>\xa0 ',
#  '<a data-entity-substitution="pup_linkit_media" data-entity-type="media" data-entity-uuid="ca9a4da0-2b70-44c7-8feb-6cd7741be9ec" href="https://www.irs.gov/pub/irs-soi/2005zipcode.zip" title="2005zipcode.zip">2005</a>\xa0 ',
#  '<a data-entity-substitution="pup_linkit_media" data-entity-type="media" data-entity-uuid="407708cd-c885-44b6-a357-919f898b75c3" href="https://www.irs.gov/pub/irs-soi/2006zipcode.zip" title="2006zipcode.zip">2006</a>\xa0 ',
#  '<a data-entity-substitution="pup_linkit_media" data-entity-type="media" data-entity-uuid="d81e5043-f8dc-4de6-b79e-010de56f8363" href="https://www.irs.gov/pub/irs-soi/2007zipcode.zip" title="2007zipcode.zip">2007</a>\xa0 ',
#  '<a data-entity-substitution="pup_linkit_media" data-entity-type="media" data-entity-uuid="7c2d8d0a-c92a-4de9-8fcf-b8270c0ff6bb" href="https://www.irs.gov/pub/irs-soi/2008zipcode.zip" title="2008zipcode.zip">2008</a> \xa0',
#  '<a data-entity-substitution="pup_linkit_media" data-entity-type="media" data-entity-uuid="d6b21686-9427-48d6-af0d-d301654a15d6" href="https://www.irs.gov/pub/irs-soi/2009zipcode.zip" title="2009zipcode.zip">2009</a> \xa0',
#  '<a data-entity-substitution="pup_linkit_media" data-entity-type="media" data-entity-uuid="437f5238-e146-41e9-aad3-5741e4882acc" href="https://www.irs.gov/pub/irs-soi/2010zipcode.zip" title="2010zipcode.zip">2010</a></p>']

# %% [markdown]
# ## Shell and Jupyter
#
# Shell and Jupyter can be used together, and this becomes even more interesting.
#
# We can do things such as download all files with `zipcode.zip` file ending by first grabbing all such file names from the html page

# %%
files = !wget -q -O - https://www.irs.gov/statistics/soi-tax-stats-individual-income-tax-statistics-zip-code-data-soi | grep 'zipcode.zip' | sed 's/<a data/\n<a data/g' | grep -Po '(?<=href=")[^"]*(?=")'
files
# Out:
# ['https://www.irs.gov/pub/irs-soi/1998zipcode.zip',
#  'https://www.irs.gov/pub/irs-soi/2001zipcode.zip',
#  'https://www.irs.gov/pub/irs-soi/2002zipcode.zip',
#  'https://www.irs.gov/pub/irs-soi/2004zipcode.zip',
#  'https://www.irs.gov/pub/irs-soi/2005zipcode.zip',
#  'https://www.irs.gov/pub/irs-soi/2006zipcode.zip',
#  'https://www.irs.gov/pub/irs-soi/2007zipcode.zip',
#  'https://www.irs.gov/pub/irs-soi/2008zipcode.zip',
#  'https://www.irs.gov/pub/irs-soi/2009zipcode.zip',
#  'https://www.irs.gov/pub/irs-soi/2010zipcode.zip']

# %% [markdown]
# ### Passing Jupyter variables to shell
#
# We can write a python loop to download each file

# %%
for f in files[:3]:
    ! wget {f}
# Out:
# --2018-04-22 13:25:06--  https://www.irs.gov/pub/irs-soi/1998zipcode.zip
# Resolving www.irs.gov (www.irs.gov)... 92.123.57.164, 2001:578:1a:181::f50, 2001:578:1a:186::f50
# Connecting to www.irs.gov (www.irs.gov)|92.123.57.164|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22284639 (21M) [application/zip]
# Saving to: ‘1998zipcode.zip’
#
# 1998zipcode.zip     100%[===================>]  21.25M  15.6MB/s    in 1.4s
#
# 2018-04-22 13:25:07 (15.6 MB/s) - ‘1998zipcode.zip’ saved [22284639/22284639]
#
# --2018-04-22 13:25:07--  https://www.irs.gov/pub/irs-soi/2001zipcode.zip
# Resolving www.irs.gov (www.irs.gov)... 92.123.57.164, 2001:578:1a:186::f50, 2001:578:1a:181::f50
# Connecting to www.irs.gov (www.irs.gov)|92.123.57.164|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17521308 (17M) [application/zip]
# Saving to: ‘2001zipcode.zip’
#
# 2001zipcode.zip     100%[===================>]  16.71M  16.2MB/s    in 1.0s
#
# 2018-04-22 13:25:09 (16.2 MB/s) - ‘2001zipcode.zip’ saved [17521308/17521308]
#
# --2018-04-22 13:25:09--  https://www.irs.gov/pub/irs-soi/2002zipcode.zip
# Resolving www.irs.gov (www.irs.gov)... 92.123.57.164, 2001:578:1a:181::f50, 2001:578:1a:186::f50
# Connecting to www.irs.gov (www.irs.gov)|92.123.57.164|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19072213 (18M) [application/zip]
# Saving to: ‘2002zipcode.zip’
#
# 2002zipcode.zip     100%[===================>]  18.19M  17.2MB/s    in 1.1s
#
# 2018-04-22 13:25:10 (17.2 MB/s) - ‘2002zipcode.zip’ saved [19072213/19072213]

# %% [markdown]
# ## Deciphering the NBA stats API
#
# NBA provides a nice website for all data related to the tornament: [http://stat.nba.com](http://stat.nba.com). For example, in order to navigate to the shooting records for Stephen Curry, you navigate their menus to get to here:
#
# > [http://stats.nba.com/player/201939/shooting/?Season=2016-17&SeasonType=Regular%20Season](http://stats.nba.com/player/201939/shooting/?Season=2016-17&SeasonType=Regular%20Season)
#
# Here, we see some information related to our choices:
# - Season: 2016-17
# - SeasonType: Regular Season ([%20 is character code for space](https://en.wikipedia.org/wiki/Percent-encoding#Character_data))
# - Player: 201939 (less obvious)
#
# This type of URL is using a [GET method](https://www.w3schools.com/tags/ref_httpmethods.asp). When your URLs are very long, it is usually passing a series of variables and values to the web page. There are tools such as this [online URL parser](https://www.freeformatter.com/url-parser-query-string-splitter.html). Try passing in the URL.
#
# Knowledge of how web sites work is useful for data science since there is so much interaction through the web.

# %%
useragent = "\"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9\""
playerurl = "\"http://stats.nba.com/stats/commonallplayers?LeagueID=00&Season=2015-16&IsOnlyCurrentSeason=1\""
json_str = !wget -q -O - --user-agent={useragent} {playerurl}

# %% [markdown]
# Above defines a url to download data from. Also, it defines an argument for what is called a User Agent. User agent allows you to mimic any browser. This is useful since websites can return different content depending on the browser users are on.
#
# In the case of NBA data, they block programatic scraping of websites by simple use of `wget`. However, by passing in the user agent string, we pretend that our connection is a user using a Mozilla-type browser on OS X.

# %%
json_str[0]
# Out:
# '{"resource":"commonallplayers","parameters":{"LeagueID":"00","Season":"2015-16","IsOnlyCurrentSeason":1},"resultSets":[{"name":"CommonAllPlayers","headers":["PERSON_ID","DISPLAY_LAST_COMMA_FIRST","DISPLAY_FIRST_LAST","ROSTERSTATUS","FROM_YEAR","TO_YEAR","PLAYERCODE","TEAM_ID","TEAM_CITY","TEAM_NAME","TEAM_ABBREVIATION","TEAM_CODE","GAMES_PLAYED_FLAG"],"rowSet":[[203919,"Adams, Jordan","Jordan Adams",1,"2014","2015","jordan_adams",1610612763,"Memphis","Grizzlies","MEM","grizzlies","Y"],[1626146,"Alexander, Cliff","Cliff Alexander",1,"2015","2015","cliff_alexander",1610612757,"Portland","Trail Blazers","POR","blazers","Y"],[200811,"Amundson, Lou","Lou Amundson",1,"2006","2015","lou_amundson",1610612752,"New York","Knicks","NYK","knicks","Y"],[2365,"Andersen, Chris","Chris Andersen",1,"2001","2016","chris_andersen",1610612763,"Memphis","Grizzlies","MEM","grizzlies","Y"],[202341,"Anderson, James","James Anderson",1,"2010","2015","james_anderson",1610612758,"Sacramento","Kings","SAC","kings","Y"],[203648,"Antetokounmpo, Thanasis","Thanasis Antetokounmpo",0,"2015","2015","thanasis_antetokounmpo",0,"","","","","Y"],[203951,"Appling, Keith","Keith Appling",0,"2015","2015","keith_appling",0,"","","","","Y"],[201965,"Ayres, Jeff","Jeff Ayres",1,"2009","2015","jeff_ayres",1610612746,"LA","Clippers","LAC","clippers","Y"],[203946,"Bairstow, Cameron","Cameron Bairstow",1,"2014","2015","cameron_bairstow",1610612741,"Chicago","Bulls","CHI","bulls","Y"],[203946,"Bairstow, Cameron","Cameron Bairstow",1,"2014","2015","cameron_bairstow",1610612765,"Detroit","Pistons","DET","pistons","Y"],[200745,"Bargnani, Andrea","Andrea Bargnani",0,"2006","2015","andrea_bargnani",0,"","","","","Y"],[201971,"Blair, DeJuan","DeJuan Blair",0,"2009","2015","dejuan_blair",0,"","","","","Y"],[2581,"Blake, Steve","Steve Blake",1,"2003","2015","steve_blake",1610612765,"Detroit","Pistons","DET","pistons","Y"],[101106,"Bogut, Andrew","Andrew Bogut",1,"2005","2017","andrew_bogut",1610612744,"Golden State","Warriors","GSW","warriors","Y"],[2588,"Bonner, Matt","Matt Bonner",1,"2004","2015","matt_bonner",1610612759,"San Antonio","Spurs","SAS","spurs","Y"],[2547,"Bosh, Chris","Chris Bosh",1,"2003","2016","chris_bosh",1610612748,"Miami","Heat","MIA","heat","Y"],[1882,"Brand, Elton","Elton Brand",1,"1999","2015","elton_brand",1610612755,"Philadelphia","76ers","PHI","sixers","Y"],[977,"Bryant, Kobe","Kobe Bryant",1,"1996","2015","kobe_bryant",1610612747,"Los Angeles","Lakers","LAL","lakers","Y"],[201978,"Budinger, Chase","Chase Budinger",1,"2009","2015","chase_budinger",1610612756,"Phoenix","Suns","PHX","suns","Y"],[2406,"Butler, Caron","Caron Butler",1,"2002","2015","caron_butler",1610612758,"Sacramento","Kings","SAC","kings","Y"],[2446,"Butler, Rasual","Rasual Butler",0,"2002","2015","rasual_butler",0,"","","","","Y"],[1626262,"Clarke, Coty","Coty Clarke",0,"2015","2015","coty_clarke",0,"","","","","Y"],[203142,"Copeland, Chris","Chris Copeland",0,"2012","2015","chris_copeland",0,"","","","","Y"],[203955,"Cotton, Bryce","Bryce Cotton",1,"2014","2015","bryce_cotton",1610612763,"Memphis","Grizzlies","MEM","grizzlies","Y"],[203099,"Cunningham, Jared","Jared Cunningham",0,"2012","2015","jared_cunningham",0,"","","","","Y"],[1626183,"Dawson, Branden","Branden Dawson",1,"2015","2015","branden_dawson",1610612746,"LA","Clippers","LAC","clippers","Y"],[1626214,"Dejean-Jones, Bryce","Bryce Dejean-Jones",0,"2015","2015","bryce_dejean-jones",0,"","","","","Y"],[201962,"Douglas, Toney","Toney Douglas",1,"2009","2016","toney_douglas",1610612740,"New Orleans","Pelicans","NOP","pelicans","Y"],[1626251,"Dukan, Duje","Duje Dukan",1,"2015","2015","duje_dukan",1610612758,"Sacramento","Kings","SAC","kings","Y"],[1495,"Duncan, Tim","Tim Duncan",1,"1997","2015","tim_duncan",1610612759,"San Antonio","Spurs","SAS","spurs","Y"],[203921,"Early, Cleanthony","Cleanthony Early",1,"2014","2015","cleanthony_early",1610612752,"New York","Knicks","NYK","knicks","Y"],[203105,"Ezeli, Festus","Festus Ezeli",1,"2 ...

# %% [markdown]
# This is what is called the json format (Javascript object notation) and is becoming one of the widely used standards in data formats.
#
# In fact, Jupyter notebooks are entirely in json format.

# %%
! head 03-Data-collection-and-manipulation.ipynb
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Data collection and manipulation\n",
#     "\n",
#     "- Common shell commands for interactions outside programming environment\n",
#     "    - Downloading files from a URL\n",

# %% [markdown]
# Json format is very similar to Python dictionary: i.e., key and values.
#
# There are built-in libraries to work with json files formats. We read the output of `wget` command into a python variable: `json_str`. Now, we can parse that string with the `json` library.

# %%
import json
data = json.loads(json_str[0])
data
# Out:
# {'parameters': {'IsOnlyCurrentSeason': 1,
#   'LeagueID': '00',
#   'Season': '2015-16'},
#  'resource': 'commonallplayers',
#  'resultSets': [{'headers': ['PERSON_ID',
#     'DISPLAY_LAST_COMMA_FIRST',
#     'DISPLAY_FIRST_LAST',
#     'ROSTERSTATUS',
#     'FROM_YEAR',
#     'TO_YEAR',
#     'PLAYERCODE',
#     'TEAM_ID',
#     'TEAM_CITY',
#     'TEAM_NAME',
#     'TEAM_ABBREVIATION',
#     'TEAM_CODE',
#     'GAMES_PLAYED_FLAG'],
#    'name': 'CommonAllPlayers',
#    'rowSet': [[203919,
#      'Adams, Jordan',
#      'Jordan Adams',
#      1,
#      '2014',
#      '2015',
#      'jordan_adams',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y'],
#     [1626146,
#      'Alexander, Cliff',
#      'Cliff Alexander',
#      1,
#      '2015',
#      '2015',
#      'cliff_alexander',
#      1610612757,
#      'Portland',
#      'Trail Blazers',
#      'POR',
#      'blazers',
#      'Y'],
#     [200811,
#      'Amundson, Lou',
#      'Lou Amundson',
#      1,
#      '2006',
#      '2015',
#      'lou_amundson',
#      1610612752,
#      'New York',
#      'Knicks',
#      'NYK',
#      'knicks',
#      'Y'],
#     [2365,
#      'Andersen, Chris',
#      'Chris Andersen',
#      1,
#      '2001',
#      '2016',
#      'chris_andersen',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y'],
#     [202341,
#      'Anderson, James',
#      'James Anderson',
#      1,
#      '2010',
#      '2015',
#      'james_anderson',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      'kings',
#      'Y'],
#     [203648,
#      'Antetokounmpo, Thanasis',
#      'Thanasis Antetokounmpo',
#      0,
#      '2015',
#      '2015',
#      'thanasis_antetokounmpo',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [203951,
#      'Appling, Keith',
#      'Keith Appling',
#      0,
#      '2015',
#      '2015',
#      'keith_appling',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [201965,
#      'Ayres, Jeff',
#      'Jeff Ayres',
#      1,
#      '2009',
#      '2015',
#      'jeff_ayres',
#      1610612746,
#      'LA',
#      'Clippers',
#      'LAC',
#      'clippers',
#      'Y'],
#     [203946,
#      'Bairstow, Cameron',
#      'Cameron Bairstow',
#      1,
#      '2014',
#      '2015',
#      'cameron_bairstow',
#      1610612741,
#      'Chicago',
#      'Bulls',
#      'CHI',
#      'bulls',
#      'Y'],
#     [203946,
#      'Bairstow, Cameron',
#      'Cameron Bairstow',
#      1,
#      '2014',
#      '2015',
#      'cameron_bairstow',
#      1610612765,
#      'Detroit',
#      'Pistons',
#      'DET',
#      'pistons',
#      'Y'],
#     [200745,
#      'Bargnani, Andrea',
#      'Andrea Bargnani',
#      0,
#      '2006',
#      '2015',
#      'andrea_bargnani',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [201971,
#      'Blair, DeJuan',
#      'DeJuan Blair',
#      0,
#      '2009',
#      '2015',
#      'dejuan_blair',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [2581,
#      'Blake, Steve',
#      'Steve Blake',
#      1,
#      '2003',
#      '2015',
#      'steve_blake',
#      1610612765,
#      'Detroit',
#      'Pistons',
#      'DET',
#      'pistons',
#      'Y'],
#     [101106,
#      'Bogut, Andrew',
#      'Andrew Bogut',
#      1,
#      '2005',
#      '2017',
#      'andrew_bogut',
#      1610612744,
#      'Golden State',
#      'Warriors',
#      'GSW',
#      'warriors',
#      'Y'],
#     [2588,
#      'Bonner, Matt',
#      'Matt Bonner',
#      1,
#      '2004',
#      '2015',
#      'matt_bonner',
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      'spurs',
#      'Y'],
#     [2547,
#      'Bosh, Chris',
#      'Chris Bosh',
#      1,
#      '2003',
#      '2016',
#      'chris_bosh',
#      1610612748,
#      'Miami',
#      'Heat',
#      'MIA',
#      'heat',
#      'Y'],
#     [1882,
#      'Brand, Elton',
#      'Elton Brand',
#      1,
#      '1999',
#      '2015',
#      'elton_brand',
#      1610612755,
#      'Philadelphia',
#      '76ers',
#      'PHI',
#      'sixers',
#      'Y'],
#     [977,
#      'Bryant, Kobe',
#      'Kobe Bryant',
#      1,
#      '1996',
#      '2015',
#      'kobe_bryant',
#      1610612747,
#      'Los Angeles',
#      'Lakers',
#      'LAL',
#      'lakers',
#      'Y'],
#     [201978,
#      'Budinger, Chase',
#      'Chase Budinger',
#      1,
#      '2009',
#      '2015',
#      'chase_budinger',
#      1610612756,
#      'Phoenix',
#      'Suns',
#      'PHX',
#      'suns',
#      'Y'],
#     [2406,
#      'Butler, Caron',
#      'Caron Butler',
#      1,
#      '2002',
#      '2015',
#      'caron_butler',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      'kings',
#      'Y'],
#     [2446,
#      'Butler, Rasual',
#      'Rasual Butler',
#      0,
#      '2002',
#      '2015',
#      'rasual_butler',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [1626262,
#      'Clarke, Coty',
#      'Coty Clarke',
#      0,
#      '2015',
#      '2015',
#      'coty_clarke',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [203142,
#      'Copeland, Chris',
#      'Chris Copeland',
#      0,
#      '2012',
#      '2015',
#      'chris_copeland',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [203955,
#      'Cotton, Bryce',
#      'Bryce Cotton',
#      1,
#      '2014',
#      '2015',
#      'bryce_cotton',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y'],
#     [203099,
#      'Cunningham, Jared',
#      'Jared Cunningham',
#      0,
#      '2012',
#      '2015',
#      'jared_cunningham',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [1626183,
#      'Dawson, Branden',
#      'Branden Dawson',
#      1,
#      '2015',
#      '2015',
#      'branden_dawson',
#      1610612746,
#      'LA',
#      'Clippers',
#      'LAC',
#      'clippers',
#      'Y'],
#     [1626214,
#      'Dejean-Jones, Bryce',
#      'Bryce Dejean-Jones',
#      0,
#      '2015',
#      '2015',
#      'bryce_dejean-jones',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [201962,
#      'Douglas, Toney',
#      'Toney Douglas',
#      1,
#      '2009',
#      '2016',
#      'toney_douglas',
#      1610612740,
#      'New Orleans',
#      'Pelicans',
#      'NOP',
#      'pelicans',
#      'Y'],
#     [1626251,
#      'Dukan, Duje',
#      'Duje Dukan',
#      1,
#      '2015',
#      '2015',
#      'duje_dukan',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      'kings',
#      'Y'],
#     [1495,
#      'Duncan, Tim',
#      'Tim Duncan',
#      1,
#      '1997',
#      '2015',
#      'tim_duncan',
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      'spurs',
#      'Y'],
#     [203921,
#      'Early, Cleanthony',
#      'Cleanthony Early',
#      1,
#      '2014',
#      '2015',
#      'cleanthony_early',
#      1610612752,
#      'New York',
#      'Knicks',
#      'NYK',
#      'knicks',
#      'Y'],
#     [203105,
#      'Ezeli, Festus',
#      'Festus Ezeli',
#      1,
#      '2012',
#      '2016',
#      'festus_ezeli',
#      1610612744,
#      'Golden State',
#      'Warriors',
#      'GSW',
#      'warriors',
#      'Y'],
#     [200770,
#      'Farmar, Jordan',
#      'Jordan Farmar',
#      1,
#      '2006',
#      '2016',
#      'jordan_farmar',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y'],
#     [202690,
#      'Fredette, Jimmer',
#      'Jimmer Fredette',
#      0,
#      '2011',
#      '2015',
#      'jimmer_fredette',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [708,
#      'Garnett, Kevin',
#      'Kevin Garnett',
#      1,
#      '1995',
#      '2015',
#      'kevin_garnett',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y'],
#     [202087,
#      'Gee, Alonzo',
#      'Alonzo Gee',
#      1,
#      '2009',
#      '2016',
#      'alonzo_gee',
#      1610612740,
#      'New Orleans',
#      'Pelicans',
#      'NOP',
#      'pelicans',
#      'Y'],
#     [2400,
#      'Gooden, Drew',
#      'Drew Gooden',
#      1,
#      '2002',
#      '2015',
#      'drew_gooden',
#      1610612764,
#      'Washington',
#      'Wizards',
#      'WAS',
#      'wizards',
#      'Y'],
#     [202726,
#      'Goudelock, Andrew',
#      'Andrew Goudelock',
#      1,
#      '2011',
#      '2015',
#      'andrew_goudelock',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      'rockets',
#      'Y'],
#     [203475,
#      'Green, Erick',
#      'Erick Green',
#      0,
#      '2014',
#      '2015',
#      'erick_green',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [203268,
#      'Gutierrez, Jorge',
#      'Jorge Gutierrez',
#      1,
#      '2013',
#      '2015',
#      'jorge_gutierrez',
#      1610612766,
#      'Charlotte',
#      'Hornets',
#      'CHA',
#      'hornets',
#      'Y'],
#     [203798,
#      'Hairston, PJ',
#      'PJ Hairston',
#      1,
#      '2014',
#      '2015',
#      'pj_hairston',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      'grizzlies',
#      'Y'],
#     [202706,
#      'Hamilton, Jordan',
#      'Jordan Hamilton',
#      1,
#      '2011',
#      '2015',
#      'jordan_hamilton',
#      1610612740,
#      'New Orleans',
#      'Pelicans',
#      'NOP',
#      'pelicans',
#      'Y'],
#     [201946,
#      'Hansbrough, Tyler',
#      'Tyler Hansbrough',
#      1,
#      '2009',
#      '2015',
#      'tyler_hansbrough',
#      1610612766,
#      'Charlotte',
#      'Hornets',
#      'CHA',
#      'hornets',
#      'Y'],
#     [101236,
#      'Hayes, Chuck',
#      'Chuck Hayes',
#      0,
#      '2005',
#      '2015',
#      'chuck_hayes',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [201581,
#      'Hickson, JJ',
#      'JJ Hickson',
#      1,
#      '2008',
#      '2015',
#      'jj_hickson',
#      1610612764,
#      'Washington',
#      'Wizards',
#      'WAS',
#      'wizards',
#      'Y'],
#     [2550,
#      'Hinrich, Kirk',
#      'Kirk Hinrich',
#      1,
#      '2003',
#      '2015',
#      'kirk_hinrich',
#      1610612737,
#      'Atlanta',
#      'Hawks',
#      'ATL',
#      'hawks',
#      'Y'],
#     [204066,
#      'Holland, John',
#      'John Holland',
#      1,
#      '2015',
#      '2017',
#      'john_holland',
#      1610612738,
#      'Boston',
#      'Celtics',
#      'BOS',
#      'celtics',
#      'Y'],
#     [200797,
#      'Hollins, Ryan',
#      'Ryan Hollins',
#      0,
#      '2006',
#      '2015',
#      'ryan_hollins',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [1626273,
#      'Huertas, Marcelo',
#      'Marcelo Huertas',
#      1,
#      '2015',
#      '2016',
#      'marcelo_huertas',
#      1610612747,
#      'Los Angeles',
#      'Lakers',
#      'LAL',
#      'lakers',
#      'Y'],
#     [203996,
#      'Inglis, Damien',
#      'Damien Inglis',
#      1,
#      '2014',
#      '2015',
#      'damien_inglis',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      'bucks',
#      'Y'],
#     [203928,
#      'Jefferson, Cory',
#      'Cory Jefferson',
#      0,
#      '2014',
#      '2015',
#      'cory_jefferson',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [203098,
#      'Jenkins, John',
#      'John Jenkins',
#      1,
#      '2012',
#      '2016',
#      'john_jenkins',
#      1610612756,
#      'Phoenix',
#      'Suns',
#      'PHX',
#      'suns',
#      'Y'],
#     [203187,
#      'Johnson, Chris',
#      'Chris Johnson',
#      1,
#      '2012',
#      '2015',
#      'chris_johnson',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      'jazz',
#      'Y'],
#     [203111,
#      'Johnson, Orlando',
#      'Orlando Johnson',
#      0,
#      '2012',
#      '2015',
#      'orlando_johnson',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [203093,
#      'Jones, Terrence',
#      'Terrence Jones',
#      1,
#      '2012',
#      '2016',
#      'terrence_jones',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      'rockets',
#      'Y'],
#     [2549,
#      'Kaman, Chris',
#      'Chris Kaman',
#      1,
#      '2003',
#      '2015',
#      'chris_kaman',
#      1610612757,
#      'Portland',
#      'Trail Blazers',
#      'POR',
#      'blazers',
#      'Y'],
#     [203508,
#      'Karasev, Sergey',
#      'Sergey Karasev',
#      1,
#      '2013',
#      '2015',
#      'sergey_karasev',
#      1610612751,
#      'Brooklyn',
#      'Nets',
#      'BKN',
#      'nets',
#      'Y'],
#     [201619,
#      'Kaun, Sasha',
#      'Sasha Kaun',
#      1,
#      '2015',
#      '2015',
#      'sasha_kaun',
#      1610612739,
#      'Cleveland',
#      'Cavaliers',
#      'CLE',
#      'cavaliers',
#      'Y'],
#     [201171,
#      'Landry, Carl',
#      'Carl Landry',
#      1,
#      '2007',
#      '2015',
#      'carl_landry',
#      1610612755,
#      'Philadelphia',
#      '76ers',
#      'PHI',
#      'sixers',
#      'Y'],
#     [203906,
#      'Marble, Devyn',
#      'Devyn Marble',
#      1,
#      '2014',
#      '2015',
#      'devyn_marble',
#      1610612753,
#      'Orlando',
#      'Magic',
#      'ORL',
#      'magic',
#      'Y'],
#     [203088,
#      'Marshall, Kendall',
#      'Kendall Marshall',
#      1,
#      '2012',
#      '2015',
#      'kendall_marshall',
#      1610612755,
#      'Philadelphia',
#      '76ers',
#      'PHI',
#      'sixers',
#      'Y'],
#     [2755,
#      'Martin, Kevin',
#      'Kevin Martin',
#      1,
#      '2004',
#      '2015',
#      'kevin_martin',
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      'spurs',
#      'Y'],
#     [201564,
#      'Mayo, O.J.',
#      'O.J. Mayo',
#      1,
#      '2008',
#      '2015',
#      'o.j._mayo',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      'bucks',
#      'Y'],
#     [203492,
#      'McCallum, Ray',
#      'Ray McCallum',
#      0,
#      '2013',
#      '2015',
#      'ray_mccallum',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [203956,
#      'McGary, Mitch',
#      'Mitch McGary',
#      1,
#      '2014',
#      '2015',
#      'mitch_mcgary',
#      1610612760,
#      'Oklahoma City',
#      'Thunder',
#      'OKC',
#      'thunder',
#      'Y'],
#     [203895,
#      'McRae, Jordan',
#      'Jordan McRae',
#      1,
#      '2015',
#      '2016',
#      'jordan_mcrae',
#      1610612739,
#      'Cleveland',
#      'Cavaliers',
#      'CLE',
#      'cavaliers',
#      'Y'],
#     [1889,
#      'Miller, Andre',
#      'Andre Miller',
#      1,
#      '1999',
#      '2015',
#      'andre_miller',
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      'spurs',
#      'Y'],
#     [1737,
#      'Mohammed, Nazr',
#      'Nazr Mohammed',
#      1,
#      '1998',
#      '2015',
#      'nazr_mohammed',
#      1610612760,
#      'Oklahoma City',
#      'Thunder',
#      'OKC',
#      'thunder',
#      'Y'],
#     [1626242,
#      'Montero, Luis',
#      'Luis Montero',
#      1,
#      '2015',
#      '2017',
#      'luis_montero',
#      1610612757,
#      'Portland',
#      'Trail Blazers',
#      'POR',
#      'blazers',
#      'Y'],
#     [200779,
#      'Novak, Steve',
#      'Steve Novak',
#      1,
#      '2006',
#      '2016',
#      'steve_novak',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      'bucks',
#      'Y'],
#     [1626266,
#      "O'Brien, JJ",
#      "JJ O'Brien",
#      0,
#      '2015',
#      '2015',
#      "jj_o'brien",
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [203123,
#      'Papanikolaou, Kostas',
#      'Kostas Papanikolaou',
#      0,
#      '2014',
#      '2015',
#      'kostas_papanikolaou',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [203934,
#      'Patterson, Lamar',
#      'Lamar Patterson',
#      1,
#      '2015',
#      '2016',
#      'lamar_patterson',
#      1610612737,
#      'Atlanta',
#      'Hawks',
#      'ATL',
#      'hawks',
#      'Y'],
#     [201593,
#      'Pekovic, Nikola',
#      'Nikola Pekovic',
#      1,
#      '2010',
#      '2016',
#      'nikola_pekovic',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y'],
#     [202353,
#      'Pleiss, Tibor',
#      'Tibor Pleiss',
#      1,
#      '2015',
#      '2015',
#      'tibor_pleiss',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      'jazz',
#      'Y'],
#     [203515,
#      'Pressey, Phil',
#      'Phil Pressey',
#      0,
#      '2013',
#      '2015',
#      'phil_pressey',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [203143,
#      'Prigioni, Pablo',
#      'Pablo Prigioni',
#      1,
#      '2012',
#      '2015',
#      'pablo_prigioni',
#      1610612746,
#      'LA',
#      'Clippers',
#      'LAC',
#      'clippers',
#      'Y'],
#     [2419,
#      'Prince, Tayshaun',
#      'Tayshaun Prince',
#      1,
#      '2002',
#      '2015',
#      'tayshaun_prince',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y'],
#     [101126,
#      'Robinson, Nate',
#      'Nate Robinson',
#      0,
#      '2005',
#      '2015',
#      'nate_robinson',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [203135,
#      'Sacre, Robert',
#      'Robert Sacre',
#      1,
#      '2012',
#      '2015',
#      'robert_sacre',
#      1610612747,
#      'Los Angeles',
#      'Lakers',
#      'LAL',
#      'lakers',
#      'Y'],
#     [2449,
#      'Scola, Luis',
#      'Luis Scola',
#      1,
#      '2007',
#      '2016',
#      'luis_scola',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      'raptors',
#      'Y'],
#     [203156,
#      'Sims, Henry',
#      'Henry Sims',
#      1,
#      '2012',
#      '2015',
#      'henry_sims',
#      1610612751,
#      'Brooklyn',
#      'Nets',
#      'BKN',
#      'nets',
#      'Y'],
#     [202388,
#      'Sloan, Donald',
#      'Donald Sloan',
#      1,
#      '2011',
#      '2015',
#      'donald_sloan',
#      1610612751,
#      'Brooklyn',
#      'Nets',
#      'BKN',
#      'nets',
#      'Y'],
#     [202962,
#      'Smith, Greg',
#      'Greg Smith',
#      1,
#      '2011',
#      '2015',
#      'greg_smith',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      'timberwolves',
#      'Y'],
#     [2746,
#      'Smith, Josh',
#      'Josh Smith',
#      1,
#      '2004',
#      '2017',
#      'josh_smith',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      'rockets',
#      'Y'],
#     [203893,
#      'Smith, Russ',
#      'Russ Smith',
#      0,
#      '2014',
#      '2015',
#      'russ_smith',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [1627293,
#      'Stepheson, Alex',
#      'Alex Stepheson',
#      0,
#      '2015',
#      '2015',
#      'alex_stepheson',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [2405,
#      "Stoudemire, Amar'e",
#      "Amar'e Stoudemire",
#      1,
#      '2002',
#      '2015',
#      "amar'e_stoudemire",
#      1610612748,
#      'Miami',
#      'Heat',
#      'MIA',
#      'heat',
#      'Y'],
#     [201155,
#      'Stuckey, Rodney',
#      'Rodney Stuckey',
#      1,
#      '2007',
#      '2016',
#      'rodney_stuckey',
#      1610612754,
#      'Indiana',
#      'Pacers',
#      'IND',
#      'pacers',
#      'Y'],
#     [203096,
#      'Sullinger, Jared',
#      'Jared Sullinger',
#      1,
#      '2012',
#      '2016',
#      'jared_sullinger',
#      1610612738,
#      'Boston',
#      'Celtics',
#      'BOS',
#      'celtics',
#      'Y'],
#     [203138,
#      'Thompson, Hollis',
#      'Hollis Thompson',
#      1,
#      '2013',
#      '2016',
#      'hollis_thompson',
#      1610612755,
#      'Philadelphia',
#      '76ers',
#      'PHI',
#      'sixers',
#      'Y'],
#     [201574,
#      'Thompson, Jason',
#      'Jason Thompson',
#      1,
#      '2008',
#      '2015',
#      'jason_thompson',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      'raptors',
#      'Y'],
#     [201977,
#      'Thornton, Marcus',
#      'Marcus Thornton',
#      1,
#      '2009',
#      '2016',
#      'marcus_thornton',
#      1610612764,
#      'Washington',
#      'Wizards',
#      'WAS',
#      'wizards',
#      'Y'],
#     [2760,
#      'Varejao, Anderson',
#      'Anderson Varejao',
#      1,
#      '2004',
#      '2016',
#      'anderson_varejao',
#      1610612744,
#      'Golden State',
#      'Warriors',
#      'GSW',
#      'warriors',
#      'Y'],
#     [202349,
#      'Vasquez, Greivis',
#      'Greivis Vasquez',
#      1,
#      '2010',
#      '2016',
#      'greivis_vasquez',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      'bucks',
#      'Y'],
#     [101111,
#      'Villanueva, Charlie',
#      'Charlie Villanueva',
#      1,
#      '2005',
#      '2015',
#      'charlie_villanueva',
#      1610612742,
#      'Dallas',
#      'Mavericks',
#      'DAL',
#      'mavericks',
#      'Y'],
#     [201603,
#      'Weems, Sonny',
#      'Sonny Weems',
#      0,
#      '2008',
#      '2015',
#      'sonny_weems',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [203963,
#      'Whittington, Shayne',
#      'Shayne Whittington',
#      1,
#      '2014',
#      '2015',
#      'shayne_whittington',
#      1610612754,
#      'Indiana',
#      'Pacers',
#      'IND',
#      'pacers',
#      'Y'],
#     [202343,
#      'Williams, Elliot',
#      'Elliot Williams',
#      0,
#      '2010',
#      '2015',
#      'elliot_williams',
#      0,
#      '',
#      '',
#      '',
#      '',
#      'Y'],
#     [2590,
#      'Williams, Mo',
#      'Mo Williams',
#      1,
#      '2003',
#      '2015',
#      'mo_williams',
#      1610612739,
#      'Cleveland',
#      'Cavaliers',
#      'CLE',
#      'cavaliers',
#      'Y'],
#     [2748,
#      'Wright, Dorell',
#      'Dorell Wright',
#      1,
#      '2004',
#      '2015',
#      'dorell_wright',
#      1610612748,
#      'Miami',
#      'Heat',
#      'MIA',
#      'heat',
#      'Y'],
#     [203100,
#      'Wroten, Tony',
#      'Tony Wroten',
#      1,
#      '2012',
#      '2015',
#      'tony_wroten',
#      1610612752,
#      'New York',
#      'Knicks',
#      'NYK',
#      'knicks',
#      'Y']]}]}

# %%
data.keys()
# Out:
# dict_keys(['resource', 'parameters', 'resultSets'])

# %%
data['resultSets'][0].keys()
# Out:
# dict_keys(['name', 'headers', 'rowSet'])

# %%
data['resultSets'][0]
# Out:
# {'headers': ['PERSON_ID',
#   'DISPLAY_LAST_COMMA_FIRST',
#   'DISPLAY_FIRST_LAST',
#   'ROSTERSTATUS',
#   'FROM_YEAR',
#   'TO_YEAR',
#   'PLAYERCODE',
#   'TEAM_ID',
#   'TEAM_CITY',
#   'TEAM_NAME',
#   'TEAM_ABBREVIATION',
#   'TEAM_CODE',
#   'GAMES_PLAYED_FLAG'],
#  'name': 'CommonAllPlayers',
#  'rowSet': [[203919,
#    'Adams, Jordan',
#    'Jordan Adams',
#    1,
#    '2014',
#    '2015',
#    'jordan_adams',
#    1610612763,
#    'Memphis',
#    'Grizzlies',
#    'MEM',
#    'grizzlies',
#    'Y'],
#   [1626146,
#    'Alexander, Cliff',
#    'Cliff Alexander',
#    1,
#    '2015',
#    '2015',
#    'cliff_alexander',
#    1610612757,
#    'Portland',
#    'Trail Blazers',
#    'POR',
#    'blazers',
#    'Y'],
#   [200811,
#    'Amundson, Lou',
#    'Lou Amundson',
#    1,
#    '2006',
#    '2015',
#    'lou_amundson',
#    1610612752,
#    'New York',
#    'Knicks',
#    'NYK',
#    'knicks',
#    'Y'],
#   [2365,
#    'Andersen, Chris',
#    'Chris Andersen',
#    1,
#    '2001',
#    '2016',
#    'chris_andersen',
#    1610612763,
#    'Memphis',
#    'Grizzlies',
#    'MEM',
#    'grizzlies',
#    'Y'],
#   [202341,
#    'Anderson, James',
#    'James Anderson',
#    1,
#    '2010',
#    '2015',
#    'james_anderson',
#    1610612758,
#    'Sacramento',
#    'Kings',
#    'SAC',
#    'kings',
#    'Y'],
#   [203648,
#    'Antetokounmpo, Thanasis',
#    'Thanasis Antetokounmpo',
#    0,
#    '2015',
#    '2015',
#    'thanasis_antetokounmpo',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [203951,
#    'Appling, Keith',
#    'Keith Appling',
#    0,
#    '2015',
#    '2015',
#    'keith_appling',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [201965,
#    'Ayres, Jeff',
#    'Jeff Ayres',
#    1,
#    '2009',
#    '2015',
#    'jeff_ayres',
#    1610612746,
#    'LA',
#    'Clippers',
#    'LAC',
#    'clippers',
#    'Y'],
#   [203946,
#    'Bairstow, Cameron',
#    'Cameron Bairstow',
#    1,
#    '2014',
#    '2015',
#    'cameron_bairstow',
#    1610612741,
#    'Chicago',
#    'Bulls',
#    'CHI',
#    'bulls',
#    'Y'],
#   [203946,
#    'Bairstow, Cameron',
#    'Cameron Bairstow',
#    1,
#    '2014',
#    '2015',
#    'cameron_bairstow',
#    1610612765,
#    'Detroit',
#    'Pistons',
#    'DET',
#    'pistons',
#    'Y'],
#   [200745,
#    'Bargnani, Andrea',
#    'Andrea Bargnani',
#    0,
#    '2006',
#    '2015',
#    'andrea_bargnani',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [201971,
#    'Blair, DeJuan',
#    'DeJuan Blair',
#    0,
#    '2009',
#    '2015',
#    'dejuan_blair',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [2581,
#    'Blake, Steve',
#    'Steve Blake',
#    1,
#    '2003',
#    '2015',
#    'steve_blake',
#    1610612765,
#    'Detroit',
#    'Pistons',
#    'DET',
#    'pistons',
#    'Y'],
#   [101106,
#    'Bogut, Andrew',
#    'Andrew Bogut',
#    1,
#    '2005',
#    '2017',
#    'andrew_bogut',
#    1610612744,
#    'Golden State',
#    'Warriors',
#    'GSW',
#    'warriors',
#    'Y'],
#   [2588,
#    'Bonner, Matt',
#    'Matt Bonner',
#    1,
#    '2004',
#    '2015',
#    'matt_bonner',
#    1610612759,
#    'San Antonio',
#    'Spurs',
#    'SAS',
#    'spurs',
#    'Y'],
#   [2547,
#    'Bosh, Chris',
#    'Chris Bosh',
#    1,
#    '2003',
#    '2016',
#    'chris_bosh',
#    1610612748,
#    'Miami',
#    'Heat',
#    'MIA',
#    'heat',
#    'Y'],
#   [1882,
#    'Brand, Elton',
#    'Elton Brand',
#    1,
#    '1999',
#    '2015',
#    'elton_brand',
#    1610612755,
#    'Philadelphia',
#    '76ers',
#    'PHI',
#    'sixers',
#    'Y'],
#   [977,
#    'Bryant, Kobe',
#    'Kobe Bryant',
#    1,
#    '1996',
#    '2015',
#    'kobe_bryant',
#    1610612747,
#    'Los Angeles',
#    'Lakers',
#    'LAL',
#    'lakers',
#    'Y'],
#   [201978,
#    'Budinger, Chase',
#    'Chase Budinger',
#    1,
#    '2009',
#    '2015',
#    'chase_budinger',
#    1610612756,
#    'Phoenix',
#    'Suns',
#    'PHX',
#    'suns',
#    'Y'],
#   [2406,
#    'Butler, Caron',
#    'Caron Butler',
#    1,
#    '2002',
#    '2015',
#    'caron_butler',
#    1610612758,
#    'Sacramento',
#    'Kings',
#    'SAC',
#    'kings',
#    'Y'],
#   [2446,
#    'Butler, Rasual',
#    'Rasual Butler',
#    0,
#    '2002',
#    '2015',
#    'rasual_butler',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [1626262,
#    'Clarke, Coty',
#    'Coty Clarke',
#    0,
#    '2015',
#    '2015',
#    'coty_clarke',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [203142,
#    'Copeland, Chris',
#    'Chris Copeland',
#    0,
#    '2012',
#    '2015',
#    'chris_copeland',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [203955,
#    'Cotton, Bryce',
#    'Bryce Cotton',
#    1,
#    '2014',
#    '2015',
#    'bryce_cotton',
#    1610612763,
#    'Memphis',
#    'Grizzlies',
#    'MEM',
#    'grizzlies',
#    'Y'],
#   [203099,
#    'Cunningham, Jared',
#    'Jared Cunningham',
#    0,
#    '2012',
#    '2015',
#    'jared_cunningham',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [1626183,
#    'Dawson, Branden',
#    'Branden Dawson',
#    1,
#    '2015',
#    '2015',
#    'branden_dawson',
#    1610612746,
#    'LA',
#    'Clippers',
#    'LAC',
#    'clippers',
#    'Y'],
#   [1626214,
#    'Dejean-Jones, Bryce',
#    'Bryce Dejean-Jones',
#    0,
#    '2015',
#    '2015',
#    'bryce_dejean-jones',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [201962,
#    'Douglas, Toney',
#    'Toney Douglas',
#    1,
#    '2009',
#    '2016',
#    'toney_douglas',
#    1610612740,
#    'New Orleans',
#    'Pelicans',
#    'NOP',
#    'pelicans',
#    'Y'],
#   [1626251,
#    'Dukan, Duje',
#    'Duje Dukan',
#    1,
#    '2015',
#    '2015',
#    'duje_dukan',
#    1610612758,
#    'Sacramento',
#    'Kings',
#    'SAC',
#    'kings',
#    'Y'],
#   [1495,
#    'Duncan, Tim',
#    'Tim Duncan',
#    1,
#    '1997',
#    '2015',
#    'tim_duncan',
#    1610612759,
#    'San Antonio',
#    'Spurs',
#    'SAS',
#    'spurs',
#    'Y'],
#   [203921,
#    'Early, Cleanthony',
#    'Cleanthony Early',
#    1,
#    '2014',
#    '2015',
#    'cleanthony_early',
#    1610612752,
#    'New York',
#    'Knicks',
#    'NYK',
#    'knicks',
#    'Y'],
#   [203105,
#    'Ezeli, Festus',
#    'Festus Ezeli',
#    1,
#    '2012',
#    '2016',
#    'festus_ezeli',
#    1610612744,
#    'Golden State',
#    'Warriors',
#    'GSW',
#    'warriors',
#    'Y'],
#   [200770,
#    'Farmar, Jordan',
#    'Jordan Farmar',
#    1,
#    '2006',
#    '2016',
#    'jordan_farmar',
#    1610612763,
#    'Memphis',
#    'Grizzlies',
#    'MEM',
#    'grizzlies',
#    'Y'],
#   [202690,
#    'Fredette, Jimmer',
#    'Jimmer Fredette',
#    0,
#    '2011',
#    '2015',
#    'jimmer_fredette',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [708,
#    'Garnett, Kevin',
#    'Kevin Garnett',
#    1,
#    '1995',
#    '2015',
#    'kevin_garnett',
#    1610612750,
#    'Minnesota',
#    'Timberwolves',
#    'MIN',
#    'timberwolves',
#    'Y'],
#   [202087,
#    'Gee, Alonzo',
#    'Alonzo Gee',
#    1,
#    '2009',
#    '2016',
#    'alonzo_gee',
#    1610612740,
#    'New Orleans',
#    'Pelicans',
#    'NOP',
#    'pelicans',
#    'Y'],
#   [2400,
#    'Gooden, Drew',
#    'Drew Gooden',
#    1,
#    '2002',
#    '2015',
#    'drew_gooden',
#    1610612764,
#    'Washington',
#    'Wizards',
#    'WAS',
#    'wizards',
#    'Y'],
#   [202726,
#    'Goudelock, Andrew',
#    'Andrew Goudelock',
#    1,
#    '2011',
#    '2015',
#    'andrew_goudelock',
#    1610612745,
#    'Houston',
#    'Rockets',
#    'HOU',
#    'rockets',
#    'Y'],
#   [203475,
#    'Green, Erick',
#    'Erick Green',
#    0,
#    '2014',
#    '2015',
#    'erick_green',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [203268,
#    'Gutierrez, Jorge',
#    'Jorge Gutierrez',
#    1,
#    '2013',
#    '2015',
#    'jorge_gutierrez',
#    1610612766,
#    'Charlotte',
#    'Hornets',
#    'CHA',
#    'hornets',
#    'Y'],
#   [203798,
#    'Hairston, PJ',
#    'PJ Hairston',
#    1,
#    '2014',
#    '2015',
#    'pj_hairston',
#    1610612763,
#    'Memphis',
#    'Grizzlies',
#    'MEM',
#    'grizzlies',
#    'Y'],
#   [202706,
#    'Hamilton, Jordan',
#    'Jordan Hamilton',
#    1,
#    '2011',
#    '2015',
#    'jordan_hamilton',
#    1610612740,
#    'New Orleans',
#    'Pelicans',
#    'NOP',
#    'pelicans',
#    'Y'],
#   [201946,
#    'Hansbrough, Tyler',
#    'Tyler Hansbrough',
#    1,
#    '2009',
#    '2015',
#    'tyler_hansbrough',
#    1610612766,
#    'Charlotte',
#    'Hornets',
#    'CHA',
#    'hornets',
#    'Y'],
#   [101236,
#    'Hayes, Chuck',
#    'Chuck Hayes',
#    0,
#    '2005',
#    '2015',
#    'chuck_hayes',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [201581,
#    'Hickson, JJ',
#    'JJ Hickson',
#    1,
#    '2008',
#    '2015',
#    'jj_hickson',
#    1610612764,
#    'Washington',
#    'Wizards',
#    'WAS',
#    'wizards',
#    'Y'],
#   [2550,
#    'Hinrich, Kirk',
#    'Kirk Hinrich',
#    1,
#    '2003',
#    '2015',
#    'kirk_hinrich',
#    1610612737,
#    'Atlanta',
#    'Hawks',
#    'ATL',
#    'hawks',
#    'Y'],
#   [204066,
#    'Holland, John',
#    'John Holland',
#    1,
#    '2015',
#    '2017',
#    'john_holland',
#    1610612738,
#    'Boston',
#    'Celtics',
#    'BOS',
#    'celtics',
#    'Y'],
#   [200797,
#    'Hollins, Ryan',
#    'Ryan Hollins',
#    0,
#    '2006',
#    '2015',
#    'ryan_hollins',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [1626273,
#    'Huertas, Marcelo',
#    'Marcelo Huertas',
#    1,
#    '2015',
#    '2016',
#    'marcelo_huertas',
#    1610612747,
#    'Los Angeles',
#    'Lakers',
#    'LAL',
#    'lakers',
#    'Y'],
#   [203996,
#    'Inglis, Damien',
#    'Damien Inglis',
#    1,
#    '2014',
#    '2015',
#    'damien_inglis',
#    1610612749,
#    'Milwaukee',
#    'Bucks',
#    'MIL',
#    'bucks',
#    'Y'],
#   [203928,
#    'Jefferson, Cory',
#    'Cory Jefferson',
#    0,
#    '2014',
#    '2015',
#    'cory_jefferson',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [203098,
#    'Jenkins, John',
#    'John Jenkins',
#    1,
#    '2012',
#    '2016',
#    'john_jenkins',
#    1610612756,
#    'Phoenix',
#    'Suns',
#    'PHX',
#    'suns',
#    'Y'],
#   [203187,
#    'Johnson, Chris',
#    'Chris Johnson',
#    1,
#    '2012',
#    '2015',
#    'chris_johnson',
#    1610612762,
#    'Utah',
#    'Jazz',
#    'UTA',
#    'jazz',
#    'Y'],
#   [203111,
#    'Johnson, Orlando',
#    'Orlando Johnson',
#    0,
#    '2012',
#    '2015',
#    'orlando_johnson',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [203093,
#    'Jones, Terrence',
#    'Terrence Jones',
#    1,
#    '2012',
#    '2016',
#    'terrence_jones',
#    1610612745,
#    'Houston',
#    'Rockets',
#    'HOU',
#    'rockets',
#    'Y'],
#   [2549,
#    'Kaman, Chris',
#    'Chris Kaman',
#    1,
#    '2003',
#    '2015',
#    'chris_kaman',
#    1610612757,
#    'Portland',
#    'Trail Blazers',
#    'POR',
#    'blazers',
#    'Y'],
#   [203508,
#    'Karasev, Sergey',
#    'Sergey Karasev',
#    1,
#    '2013',
#    '2015',
#    'sergey_karasev',
#    1610612751,
#    'Brooklyn',
#    'Nets',
#    'BKN',
#    'nets',
#    'Y'],
#   [201619,
#    'Kaun, Sasha',
#    'Sasha Kaun',
#    1,
#    '2015',
#    '2015',
#    'sasha_kaun',
#    1610612739,
#    'Cleveland',
#    'Cavaliers',
#    'CLE',
#    'cavaliers',
#    'Y'],
#   [201171,
#    'Landry, Carl',
#    'Carl Landry',
#    1,
#    '2007',
#    '2015',
#    'carl_landry',
#    1610612755,
#    'Philadelphia',
#    '76ers',
#    'PHI',
#    'sixers',
#    'Y'],
#   [203906,
#    'Marble, Devyn',
#    'Devyn Marble',
#    1,
#    '2014',
#    '2015',
#    'devyn_marble',
#    1610612753,
#    'Orlando',
#    'Magic',
#    'ORL',
#    'magic',
#    'Y'],
#   [203088,
#    'Marshall, Kendall',
#    'Kendall Marshall',
#    1,
#    '2012',
#    '2015',
#    'kendall_marshall',
#    1610612755,
#    'Philadelphia',
#    '76ers',
#    'PHI',
#    'sixers',
#    'Y'],
#   [2755,
#    'Martin, Kevin',
#    'Kevin Martin',
#    1,
#    '2004',
#    '2015',
#    'kevin_martin',
#    1610612759,
#    'San Antonio',
#    'Spurs',
#    'SAS',
#    'spurs',
#    'Y'],
#   [201564,
#    'Mayo, O.J.',
#    'O.J. Mayo',
#    1,
#    '2008',
#    '2015',
#    'o.j._mayo',
#    1610612749,
#    'Milwaukee',
#    'Bucks',
#    'MIL',
#    'bucks',
#    'Y'],
#   [203492,
#    'McCallum, Ray',
#    'Ray McCallum',
#    0,
#    '2013',
#    '2015',
#    'ray_mccallum',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [203956,
#    'McGary, Mitch',
#    'Mitch McGary',
#    1,
#    '2014',
#    '2015',
#    'mitch_mcgary',
#    1610612760,
#    'Oklahoma City',
#    'Thunder',
#    'OKC',
#    'thunder',
#    'Y'],
#   [203895,
#    'McRae, Jordan',
#    'Jordan McRae',
#    1,
#    '2015',
#    '2016',
#    'jordan_mcrae',
#    1610612739,
#    'Cleveland',
#    'Cavaliers',
#    'CLE',
#    'cavaliers',
#    'Y'],
#   [1889,
#    'Miller, Andre',
#    'Andre Miller',
#    1,
#    '1999',
#    '2015',
#    'andre_miller',
#    1610612759,
#    'San Antonio',
#    'Spurs',
#    'SAS',
#    'spurs',
#    'Y'],
#   [1737,
#    'Mohammed, Nazr',
#    'Nazr Mohammed',
#    1,
#    '1998',
#    '2015',
#    'nazr_mohammed',
#    1610612760,
#    'Oklahoma City',
#    'Thunder',
#    'OKC',
#    'thunder',
#    'Y'],
#   [1626242,
#    'Montero, Luis',
#    'Luis Montero',
#    1,
#    '2015',
#    '2017',
#    'luis_montero',
#    1610612757,
#    'Portland',
#    'Trail Blazers',
#    'POR',
#    'blazers',
#    'Y'],
#   [200779,
#    'Novak, Steve',
#    'Steve Novak',
#    1,
#    '2006',
#    '2016',
#    'steve_novak',
#    1610612749,
#    'Milwaukee',
#    'Bucks',
#    'MIL',
#    'bucks',
#    'Y'],
#   [1626266,
#    "O'Brien, JJ",
#    "JJ O'Brien",
#    0,
#    '2015',
#    '2015',
#    "jj_o'brien",
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [203123,
#    'Papanikolaou, Kostas',
#    'Kostas Papanikolaou',
#    0,
#    '2014',
#    '2015',
#    'kostas_papanikolaou',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [203934,
#    'Patterson, Lamar',
#    'Lamar Patterson',
#    1,
#    '2015',
#    '2016',
#    'lamar_patterson',
#    1610612737,
#    'Atlanta',
#    'Hawks',
#    'ATL',
#    'hawks',
#    'Y'],
#   [201593,
#    'Pekovic, Nikola',
#    'Nikola Pekovic',
#    1,
#    '2010',
#    '2016',
#    'nikola_pekovic',
#    1610612750,
#    'Minnesota',
#    'Timberwolves',
#    'MIN',
#    'timberwolves',
#    'Y'],
#   [202353,
#    'Pleiss, Tibor',
#    'Tibor Pleiss',
#    1,
#    '2015',
#    '2015',
#    'tibor_pleiss',
#    1610612762,
#    'Utah',
#    'Jazz',
#    'UTA',
#    'jazz',
#    'Y'],
#   [203515,
#    'Pressey, Phil',
#    'Phil Pressey',
#    0,
#    '2013',
#    '2015',
#    'phil_pressey',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [203143,
#    'Prigioni, Pablo',
#    'Pablo Prigioni',
#    1,
#    '2012',
#    '2015',
#    'pablo_prigioni',
#    1610612746,
#    'LA',
#    'Clippers',
#    'LAC',
#    'clippers',
#    'Y'],
#   [2419,
#    'Prince, Tayshaun',
#    'Tayshaun Prince',
#    1,
#    '2002',
#    '2015',
#    'tayshaun_prince',
#    1610612750,
#    'Minnesota',
#    'Timberwolves',
#    'MIN',
#    'timberwolves',
#    'Y'],
#   [101126,
#    'Robinson, Nate',
#    'Nate Robinson',
#    0,
#    '2005',
#    '2015',
#    'nate_robinson',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [203135,
#    'Sacre, Robert',
#    'Robert Sacre',
#    1,
#    '2012',
#    '2015',
#    'robert_sacre',
#    1610612747,
#    'Los Angeles',
#    'Lakers',
#    'LAL',
#    'lakers',
#    'Y'],
#   [2449,
#    'Scola, Luis',
#    'Luis Scola',
#    1,
#    '2007',
#    '2016',
#    'luis_scola',
#    1610612761,
#    'Toronto',
#    'Raptors',
#    'TOR',
#    'raptors',
#    'Y'],
#   [203156,
#    'Sims, Henry',
#    'Henry Sims',
#    1,
#    '2012',
#    '2015',
#    'henry_sims',
#    1610612751,
#    'Brooklyn',
#    'Nets',
#    'BKN',
#    'nets',
#    'Y'],
#   [202388,
#    'Sloan, Donald',
#    'Donald Sloan',
#    1,
#    '2011',
#    '2015',
#    'donald_sloan',
#    1610612751,
#    'Brooklyn',
#    'Nets',
#    'BKN',
#    'nets',
#    'Y'],
#   [202962,
#    'Smith, Greg',
#    'Greg Smith',
#    1,
#    '2011',
#    '2015',
#    'greg_smith',
#    1610612750,
#    'Minnesota',
#    'Timberwolves',
#    'MIN',
#    'timberwolves',
#    'Y'],
#   [2746,
#    'Smith, Josh',
#    'Josh Smith',
#    1,
#    '2004',
#    '2017',
#    'josh_smith',
#    1610612745,
#    'Houston',
#    'Rockets',
#    'HOU',
#    'rockets',
#    'Y'],
#   [203893,
#    'Smith, Russ',
#    'Russ Smith',
#    0,
#    '2014',
#    '2015',
#    'russ_smith',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [1627293,
#    'Stepheson, Alex',
#    'Alex Stepheson',
#    0,
#    '2015',
#    '2015',
#    'alex_stepheson',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [2405,
#    "Stoudemire, Amar'e",
#    "Amar'e Stoudemire",
#    1,
#    '2002',
#    '2015',
#    "amar'e_stoudemire",
#    1610612748,
#    'Miami',
#    'Heat',
#    'MIA',
#    'heat',
#    'Y'],
#   [201155,
#    'Stuckey, Rodney',
#    'Rodney Stuckey',
#    1,
#    '2007',
#    '2016',
#    'rodney_stuckey',
#    1610612754,
#    'Indiana',
#    'Pacers',
#    'IND',
#    'pacers',
#    'Y'],
#   [203096,
#    'Sullinger, Jared',
#    'Jared Sullinger',
#    1,
#    '2012',
#    '2016',
#    'jared_sullinger',
#    1610612738,
#    'Boston',
#    'Celtics',
#    'BOS',
#    'celtics',
#    'Y'],
#   [203138,
#    'Thompson, Hollis',
#    'Hollis Thompson',
#    1,
#    '2013',
#    '2016',
#    'hollis_thompson',
#    1610612755,
#    'Philadelphia',
#    '76ers',
#    'PHI',
#    'sixers',
#    'Y'],
#   [201574,
#    'Thompson, Jason',
#    'Jason Thompson',
#    1,
#    '2008',
#    '2015',
#    'jason_thompson',
#    1610612761,
#    'Toronto',
#    'Raptors',
#    'TOR',
#    'raptors',
#    'Y'],
#   [201977,
#    'Thornton, Marcus',
#    'Marcus Thornton',
#    1,
#    '2009',
#    '2016',
#    'marcus_thornton',
#    1610612764,
#    'Washington',
#    'Wizards',
#    'WAS',
#    'wizards',
#    'Y'],
#   [2760,
#    'Varejao, Anderson',
#    'Anderson Varejao',
#    1,
#    '2004',
#    '2016',
#    'anderson_varejao',
#    1610612744,
#    'Golden State',
#    'Warriors',
#    'GSW',
#    'warriors',
#    'Y'],
#   [202349,
#    'Vasquez, Greivis',
#    'Greivis Vasquez',
#    1,
#    '2010',
#    '2016',
#    'greivis_vasquez',
#    1610612749,
#    'Milwaukee',
#    'Bucks',
#    'MIL',
#    'bucks',
#    'Y'],
#   [101111,
#    'Villanueva, Charlie',
#    'Charlie Villanueva',
#    1,
#    '2005',
#    '2015',
#    'charlie_villanueva',
#    1610612742,
#    'Dallas',
#    'Mavericks',
#    'DAL',
#    'mavericks',
#    'Y'],
#   [201603,
#    'Weems, Sonny',
#    'Sonny Weems',
#    0,
#    '2008',
#    '2015',
#    'sonny_weems',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [203963,
#    'Whittington, Shayne',
#    'Shayne Whittington',
#    1,
#    '2014',
#    '2015',
#    'shayne_whittington',
#    1610612754,
#    'Indiana',
#    'Pacers',
#    'IND',
#    'pacers',
#    'Y'],
#   [202343,
#    'Williams, Elliot',
#    'Elliot Williams',
#    0,
#    '2010',
#    '2015',
#    'elliot_williams',
#    0,
#    '',
#    '',
#    '',
#    '',
#    'Y'],
#   [2590,
#    'Williams, Mo',
#    'Mo Williams',
#    1,
#    '2003',
#    '2015',
#    'mo_williams',
#    1610612739,
#    'Cleveland',
#    'Cavaliers',
#    'CLE',
#    'cavaliers',
#    'Y'],
#   [2748,
#    'Wright, Dorell',
#    'Dorell Wright',
#    1,
#    '2004',
#    '2015',
#    'dorell_wright',
#    1610612748,
#    'Miami',
#    'Heat',
#    'MIA',
#    'heat',
#    'Y'],
#   [203100,
#    'Wroten, Tony',
#    'Tony Wroten',
#    1,
#    '2012',
#    '2015',
#    'tony_wroten',
#    1610612752,
#    'New York',
#    'Knicks',
#    'NYK',
#    'knicks',
#    'Y']]}

# %%
import pandas as pd

h = data['resultSets'][0]['headers']
d = data['resultSets'][0]['rowSet']
players = pd.DataFrame(d, columns=h)
players.head()
# Out:
#    PERSON_ID DISPLAY_LAST_COMMA_FIRST DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 0     203919            Adams, Jordan       Jordan Adams             1
# 1    1626146         Alexander, Cliff    Cliff Alexander             1
# 2     200811            Amundson, Lou       Lou Amundson             1
# 3       2365          Andersen, Chris     Chris Andersen             1
# 4     202341          Anderson, James     James Anderson             1
#
#   FROM_YEAR TO_YEAR       PLAYERCODE     TEAM_ID   TEAM_CITY      TEAM_NAME  \
# 0      2014    2015     jordan_adams  1610612763     Memphis      Grizzlies
# 1      2015    2015  cliff_alexander  1610612757    Portland  Trail Blazers
# 2      2006    2015     lou_amundson  1610612752    New York         Knicks
# 3      2001    2016   chris_andersen  1610612763     Memphis      Grizzlies
# 4      2010    2015   james_anderson  1610612758  Sacramento          Kings
#
#   TEAM_ABBREVIATION  TEAM_CODE GAMES_PLAYED_FLAG
# 0               MEM  grizzlies                 Y
# 1               POR    blazers                 Y
# 2               NYK     knicks                 Y
# 3               MEM  grizzlies                 Y
# 4               SAC      kings                 Y

# %% [markdown]
# What other data can we download using these types of URLS? It turns out that NBA does not publish (I wasn't able to find one) an official documentation, but people have come up with a [community documentation](https://github.com/seemethere/nba_py/wiki/stats.nba.com-Endpoint-Documentation).
#
# Let's work with the [shot chart](https://github.com/seemethere/nba_py/wiki/stats.nba.com-Endpoint-Documentation#shotchartdetail). The site kindly tells me [which parameters are required if none is passed](http://stats.nba.com/stats/shotchartdetail).

# %%
from urllib.parse import urlencode
from urllib.request import urlretrieve

params = {'LeagueID':'00'}
teamurl = 'http://stats.nba.com/stats/commonTeamYears?' + urlencode(params)
# !wget -q -O - --user-agent={useragent} {teamurl}
# Out:
# {"resource":"commonteamyears","parameters":{"LeagueID":"00"},"resultSets":[{"name":"TeamYears","headers":["LEAGUE_ID","TEAM_ID","MIN_YEAR","MAX_YEAR","ABBREVIATION"],"rowSet":[["00",1610612737,"1949","2017","ATL"],["00",1610612738,"1946","2017","BOS"],["00",1610612739,"1970","2017","CLE"],["00",1610612740,"2002","2017","NOP"],["00",1610612741,"1966","2017","CHI"],["00",1610612742,"1980","2017","DAL"],["00",1610612743,"1976","2017","DEN"],["00",1610612744,"1946","2017","GSW"],["00",1610612745,"1967","2017","HOU"],["00",1610612746,"1970","2017","LAC"],["00",1610612747,"1948","2017","LAL"],["00",1610612748,"1988","2017","MIA"],["00",1610612749,"1968","2017","MIL"],["00",1610612750,"1989","2017","MIN"],["00",1610612751,"1976","2017","BKN"],["00",1610612752,"1946","2017","NYK"],["00",1610612753,"1989","2017","ORL"],["00",1610612754,"1976","2017","IND"],["00",1610612755,"1949","2017","PHI"],["00",1610612756,"1968","2017","PHX"],["00",1610612757,"1970","2017","POR"],["00",1610612758,"1948","2017","SAC"],["00",1610612759,"1976","2017","SAS"],["00",1610612760,"1967","2017","OKC"],["00",1610612761,"1995","2017","TOR"],["00",1610612762,"1974","2017","UTA"],["00",1610612763,"1995","2017","MEM"],["00",1610612764,"1961","2017","WAS"],["00",1610612765,"1948","2017","DET"],["00",1610612766,"1988","2017","CHA"],["00",1610610031,"1946","1946",null],["00",1610610029,"1948","1948",null],["00",1610610025,"1946","1949",null],["00",1610610034,"1946","1949",null],["00",1610610036,"1946","1950",null],["00",1610610024,"1947","1954",null],["00",1610610027,"1949","1949",null],["00",1610610030,"1949","1952",null],["00",1610610033,"1949","1949",null],["00",1610610037,"1949","1949",null],["00",1610610023,"1949","1949",null],["00",1610610026,"1946","1946",null],["00",1610610028,"1946","1946",null],["00",1610610032,"1946","1948",null],["00",1610610035,"1946","1946",null]]}]}

# %% [markdown]
# Now that we know what a general request looks like, we can create a function to make our requests simpler.
#
# The function will do the following:
# 1. Set User Agent
# 1. Set base URL with appropriate end point
# 1. Set parameters required for query
# 1. Read JSON string into python variable
# 1. Parse JSON string into python object
# 1. Convert the objects into pandas a data frame

# %%
def get_nba_data(endpt, params, return_url=False):

    ## endpt: https://github.com/seemethere/nba_py/wiki/stats.nba.com-Endpoint-Documentation
    ## params: dictionary of parameters: i.e., {'LeagueID':'00'}
    from pandas import DataFrame
    from urllib.parse import urlencode
    import json
    
    useragent = "\"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9\""

    dataurl = "\"" + "http://stats.nba.com/stats/" + endpt + "?" + urlencode(params) + "\""
    
    # for debugging: just return the url
    if return_url:
        return(dataurl)
    
    jsonstr = !wget -q -O - --user-agent={useragent} {dataurl}
    
    data = json.loads(jsonstr[0])
    
    h = data['resultSets'][0]['headers']
    d = data['resultSets'][0]['rowSet']
    
    return(DataFrame(d, columns=h))

# %% [markdown]
# To see what URL string is returned, set `return_url=True`.

# %%
params = {'LeagueID':'00'}
get_nba_data('commonTeamYears', params, return_url=True)
# Out:
# '"http://stats.nba.com/stats/commonTeamYears?LeagueID=00"'

# %%
params = {'LeagueID':'00'}
teamdata = get_nba_data('commonTeamYears', params)
teamdata.head()
# Out:
#   LEAGUE_ID     TEAM_ID MIN_YEAR MAX_YEAR ABBREVIATION
# 0        00  1610612737     1949     2017          ATL
# 1        00  1610612738     1946     2017          BOS
# 2        00  1610612739     1970     2017          CLE
# 3        00  1610612740     2002     2017          NOP
# 4        00  1610612741     1966     2017          CHI

# %%
params = {'LeagueID':'00', 'Season': '2016-17', 'IsOnlyCurrentSeason': '1'}
plyrdata = get_nba_data('commonallplayers', params)
plyrdata.head()
# Out:
#    PERSON_ID DISPLAY_LAST_COMMA_FIRST DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 0     201582           Ajinca, Alexis      Alexis Ajinca             1
# 1     202730             Allen, Lavoy        Lavoy Allen             1
# 2       2754              Allen, Tony         Tony Allen             1
# 3       2365          Andersen, Chris     Chris Andersen             0
# 4     101187           Anderson, Alan      Alan Anderson             1
#
#   FROM_YEAR TO_YEAR      PLAYERCODE     TEAM_ID    TEAM_CITY  TEAM_NAME  \
# 0      2008    2017   alexis_ajinca  1610612740  New Orleans   Pelicans
# 1      2011    2016     lavoy_allen  1610612754      Indiana     Pacers
# 2      2004    2017      tony_allen  1610612763      Memphis  Grizzlies
# 3      2001    2016  chris_andersen           0
# 4      2005    2016   alan_anderson  1610612746           LA   Clippers
#
#   TEAM_ABBREVIATION  TEAM_CODE GAMES_PLAYED_FLAG
# 0               NOP   pelicans                 Y
# 1               IND     pacers                 Y
# 2               MEM  grizzlies                 Y
# 3                                              Y
# 4               LAC   clippers                 Y

# %% [markdown]
# Finally, we can get the shot chart detail.

# %%
params = {'PlayerID':'201935',
          'PlayerPosition':'',
          'Season':'2016-17',
          'ContextMeasure':'FGA',
          'DateFrom':'',
          'DateTo':'',
          'GameID':'',
          'GameSegment':'',
          'LastNGames':'0',
          'LeagueID':'00',
          'Location':'',
          'Month':'0',
          'OpponentTeamID':'0',
          'Outcome':'',
          'Period':'0',
          'Position':'',
          'RookieYear':'',
          'SeasonSegment':'',
          'SeasonType':'Regular Season',
          'TeamID':'0',
          'VsConference':'',
          'VsDivision':''}

shotdata = get_nba_data('shotchartdetail', params)
shotdata
# Out:
#               GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID   PLAYER_NAME  \
# 0     Shot Chart Detail  0021600013              9     201935  James Harden
# 1     Shot Chart Detail  0021600013             13     201935  James Harden
# 2     Shot Chart Detail  0021600013             22     201935  James Harden
# 3     Shot Chart Detail  0021600013             77     201935  James Harden
# 4     Shot Chart Detail  0021600013             89     201935  James Harden
# 5     Shot Chart Detail  0021600013             99     201935  James Harden
# 6     Shot Chart Detail  0021600013            111     201935  James Harden
# 7     Shot Chart Detail  0021600013            221     201935  James Harden
# 8     Shot Chart Detail  0021600013            281     201935  James Harden
# 9     Shot Chart Detail  0021600013            308     201935  James Harden
# 10    Shot Chart Detail  0021600013            332     201935  James Harden
# 11    Shot Chart Detail  0021600013            354     201935  James Harden
# 12    Shot Chart Detail  0021600013            376     201935  James Harden
# 13    Shot Chart Detail  0021600013            463     201935  James Harden
# 14    Shot Chart Detail  0021600013            471     201935  James Harden
# 15    Shot Chart Detail  0021600013            499     201935  James Harden
# 16    Shot Chart Detail  0021600013            525     201935  James Harden
# 17    Shot Chart Detail  0021600013            555     201935  James Harden
# 18    Shot Chart Detail  0021600023             18     201935  James Harden
# 19    Shot Chart Detail  0021600023             33     201935  James Harden
# 20    Shot Chart Detail  0021600023             56     201935  James Harden
# 21    Shot Chart Detail  0021600023             67     201935  James Harden
# 22    Shot Chart Detail  0021600023             98     201935  James Harden
# 23    Shot Chart Detail  0021600023            180     201935  James Harden
# 24    Shot Chart Detail  0021600023            195     201935  James Harden
# 25    Shot Chart Detail  0021600023            203     201935  James Harden
# 26    Shot Chart Detail  0021600023            242     201935  James Harden
# 27    Shot Chart Detail  0021600023            248     201935  James Harden
# 28    Shot Chart Detail  0021600023            250     201935  James Harden
# 29    Shot Chart Detail  0021600023            267     201935  James Harden
# ...                 ...         ...            ...        ...           ...
# 1501  Shot Chart Detail  0021601200            333     201935  James Harden
# 1502  Shot Chart Detail  0021601200            336     201935  James Harden
# 1503  Shot Chart Detail  0021601200            351     201935  James Harden
# 1504  Shot Chart Detail  0021601200            377     201935  James Harden
# 1505  Shot Chart Detail  0021601200            382     201935  James Harden
# 1506  Shot Chart Detail  0021601200            404     201935  James Harden
# 1507  Shot Chart Detail  0021601200            478     201935  James Harden
# 1508  Shot Chart Detail  0021601200            492     201935  James Harden
# 1509  Shot Chart Detail  0021601210             43     201935  James Harden
# 1510  Shot Chart Detail  0021601210             61     201935  James Harden
# 1511  Shot Chart Detail  0021601210             63     201935  James Harden
# 1512  Shot Chart Detail  0021601210             80     201935  James Harden
# 1513  Shot Chart Detail  0021601210             93     201935  James Harden
# 1514  Shot Chart Detail  0021601210            171     201935  James Harden
# 1515  Shot Chart Detail  0021601210            281     201935  James Harden
# 1516  Shot Chart Detail  0021601210            312     201935  James Harden
# 1517  Shot Chart Detail  0021601210            370     201935  James Harden
# 1518  Shot Chart Detail  0021601224              9     201935  James Harden
# 1519  Shot Chart Detail  0021601224             22     201935  James Harden
# 1520  Shot Chart Detail  0021601224             24     201935  James Harden
# 1521  Shot Chart Detail  0021601224             48     201935  James Harden
# 1522  Shot Chart Detail  0021601224             54     201935  James Harden
# 1523  Shot Chart Detail  0021601224             80     201935  James Harden
# 1524  Shot Chart Detail  0021601224            255     201935  James Harden
# 1525  Shot Chart Detail  0021601224            265     201935  James Harden
# 1526  Shot Chart Detail  0021601224            267     201935  James Harden
# 1527  Shot Chart Detail  0021601224            368     201935  James Harden
# 1528  Shot Chart Detail  0021601224            436     201935  James Harden
# 1529  Shot Chart Detail  0021601224            452     201935  James Harden
# 1530  Shot Chart Detail  0021601224            476     201935  James Harden
#
#          TEAM_ID        TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0     1610612745  Houston Rockets       1                 10
# 1     1610612745  Houston Rockets       1                 10
# 2     1610612745  Houston Rockets       1                  9
# 3     1610612745  Houston Rockets       1                  4
# 4     1610612745  Houston Rockets       1                  3
# 5     1610612745  Houston Rockets       1                  2
# 6     1610612745  Houston Rockets       1                  0
# 7     1610612745  Houston Rockets       2                  4
# 8     1610612745  Houston Rockets       3                 10
# 9     1610612745  Houston Rockets       3                  7
# 10    1610612745  Houston Rockets       3                  5
# 11    1610612745  Houston Rockets       3                  3
# 12    1610612745  Houston Rockets       3                  0
# 13    1610612745  Houston Rockets       4                  6
# 14    1610612745  Houston Rockets       4                  6
# 15    1610612745  Houston Rockets       4                  4
# 16    1610612745  Houston Rockets       4                  2
# 17    1610612745  Houston Rockets       4                  0
# 18    1610612745  Houston Rockets       1                  9
# 19    1610612745  Houston Rockets       1                  7
# 20    1610612745  Houston Rockets       1                  5
# 21    1610612745  Houston Rockets       1                  3
# 22    1610612745  Houston Rockets       1                  0
# 23    1610612745  Houston Rockets       2                  6
# 24    1610612745  Houston Rockets       2                  4
# 25    1610612745  Houston Rockets       2                  3
# 26    1610612745  Houston Rockets       2                  1
# 27    1610612745  Houston Rockets       2                  0
# 28    1610612745  Houston Rockets       2                  0
# 29    1610612745  Houston Rockets       3                 11
# ...          ...              ...     ...                ...
# 1501  1610612745  Houston Rockets       3                  6
# 1502  1610612745  Houston Rockets       3                  5
# 1503  1610612745  Houston Rockets       3                  4
# 1504  1610612745  Houston Rockets       3                  2
# 1505  1610612745  Houston Rockets       3                  2
# 1506  1610612745  Houston Rockets       3                  0
# 1507  1610612745  Houston Rockets       4                  5
# 1508  1610612745  Houston Rockets       4                  3
# 1509  1610612745  Houston Rockets       1                  7
# 1510  1610612745  Houston Rockets       1                  6
# 1511  1610612745  Houston Rockets       1                  6
# 1512  1610612745  Houston Rockets       1                  5
# 1513  1610612745  Houston Rockets       1                  4
# 1514  1610612745  Houston Rockets       1                  0
# 1515  1610612745  Houston Rockets       2                  2
# 1516  1610612745  Houston Rockets       3                 11
# 1517  1610612745  Houston Rockets       3                  6
# 1518  1610612745  Houston Rockets       1                 10
# 1519  1610612745  Houston Rockets       1                 10
# 1520  1610612745  Houston Rockets       1                  9
# 1521  1610612745  Houston Rockets       1                  7
# 1522  1610612745  Houston Rockets       1                  6
# 1523  1610612745  Houston Rockets       1                  3
# 1524  1610612745  Houston Rockets       2                  0
# 1525  1610612745  Houston Rockets       3                 11
# 1526  1610612745  Houston Rockets       3                 11
# 1527  1610612745  Houston Rockets       3                  0
# 1528  1610612745  Houston Rockets       4                  6
# 1529  1610612745  Houston Rockets       4                  5
# 1530  1610612745  Houston Rockets       4                  2
#
#       SECONDS_REMAINING ...          SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0                    58 ...               Center(C)  Less Than 8 ft.
# 1                    15 ...               Center(C)  Less Than 8 ft.
# 2                    14 ...    Left Side Center(LC)          24+ ft.
# 3                    16 ...               Center(C)  Less Than 8 ft.
# 4                    31 ...               Center(C)  Less Than 8 ft.
# 5                    21 ...               Center(C)  Less Than 8 ft.
# 6                    29 ...    Left Side Center(LC)          24+ ft.
# 7                    34 ...               Center(C)  Less Than 8 ft.
# 8                    31 ...           Right Side(R)          24+ ft.
# 9                    48 ...           Right Side(R)         8-16 ft.
# 10                   44 ...               Center(C)  Less Than 8 ft.
# 11                    6 ...               Center(C)  Less Than 8 ft.
# 12                   57 ...               Center(C)  Less Than 8 ft.
# 13                   59 ...               Center(C)  Less Than 8 ft.
# 14                   20 ...               Center(C)          24+ ft.
# 15                   10 ...   Right Side Center(RC)          24+ ft.
# 16                   28 ...               Center(C)  Less Than 8 ft.
# 17                    6 ...               Center(C)          24+ ft.
# 18                    9 ...               Center(C)  Less Than 8 ft.
# 19                   54 ...            Left Side(L)          24+ ft.
# 20                   14 ...               Center(C)  Less Than 8 ft.
# 21                    0 ...   Right Side Center(RC)          24+ ft.
# 22                    0 ...               Center(C)          24+ ft.
# 23                    4 ...               Center(C)          24+ ft.
# 24                   22 ...   Right Side Center(RC)          24+ ft.
# 25                   47 ...   Right Side Center(RC)        16-24 ft.
# 26                    3 ...               Center(C)        16-24 ft.
# 27                    5 ...               Center(C)  Less Than 8 ft.
# 28                    5 ...               Center(C)  Less Than 8 ft.
# 29                   23 ...            Left Side(L)         8-16 ft.
# ...                 ... ...                     ...              ...
# 1501                 16 ...               Center(C)        16-24 ft.
# 1502                 46 ...   Right Side Center(RC)          24+ ft.
# 1503                 48 ...               Center(C)          24+ ft.
# 1504                 38 ...               Center(C)  Less Than 8 ft.
# 1505                  2 ...   Right Side Center(RC)          24+ ft.
# 1506                 24 ...               Center(C)          24+ ft.
# 1507                 26 ...   Right Side Center(RC)          24+ ft.
# 1508                 37 ...               Center(C)  Less Than 8 ft.
# 1509                 35 ...               Center(C)          24+ ft.
# 1510                 46 ...               Center(C)          24+ ft.
# 1511                 34 ...               Center(C)          24+ ft.
# 1512                 41 ...               Center(C)  Less Than 8 ft.
# 1513                 32 ...    Left Side Center(LC)          24+ ft.
# 1514                  0 ...          Back Court(BC)  Back Court Shot
# 1515                 25 ...    Left Side Center(LC)          24+ ft.
# 1516                 41 ...           Right Side(R)        16-24 ft.
# 1517                 35 ...               Center(C)  Less Than 8 ft.
# 1518                 46 ...               Center(C)  Less Than 8 ft.
# 1519                  2 ...               Center(C)          24+ ft.
# 1520                 51 ...    Left Side Center(LC)          24+ ft.
# 1521                 18 ...   Right Side Center(RC)          24+ ft.
# 1522                 31 ...               Center(C)          24+ ft.
# 1523                 28 ...               Center(C)  Less Than 8 ft.
# 1524                 22 ...               Center(C)  Less Than 8 ft.
# 1525                 30 ...   Right Side Center(RC)          24+ ft.
# 1526                 24 ...   Right Side Center(RC)          24+ ft.
# 1527                 18 ...            Left Side(L)          24+ ft.
# 1528                 37 ...    Left Side Center(LC)          24+ ft.
# 1529                 17 ...    Left Side Center(LC)          24+ ft.
# 1530                 48 ...   Right Side Center(RC)          24+ ft.
#
#      SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  \
# 0                2   -24     8                   1               1   20161026
# 1                2   -13    16                   1               1   20161026
# 2               25  -142   217                   1               1   20161026
# 3                2    13    21                   1               0   20161026
# 4                1     5    11                   1               1   20161026
# 5                0     0     8                   1               0   20161026
# 6               26  -139   222                   1               0   20161026
# 7                0    -3     6                   1               1   20161026
# 8               24   243     1                   1               0   20161026
# 9               13   135    36                   1               1   20161026
# 10               1     8     8                   1               1   20161026
# 11               2     5    21                   1               0   20161026
# 12               3   -28    23                   1               1   20161026
# 13               2    -5    28                   1               1   20161026
# 14              26   -72   258                   1               0   20161026
# 15              26   137   232                   1               0   20161026
# 16               3   -31    21                   1               0   20161026
# 17              26    81   251                   1               0   20161026
# 18               0    -6    -1                   1               0   20161028
# 19              23  -232    13                   1               0   20161028
# 20               5   -25    47                   1               0   20161028
# 21              25   155   198                   1               0   20161028
# 22              24    22   244                   1               0   20161028
# 23              24   -66   239                   1               0   20161028
# 24              24   177   174                   1               1   20161028
# 25              17   125   129                   1               1   20161028
# 26              16    -7   169                   1               1   20161028
# 27               6    43    43                   1               0   20161028
# 28               1    14     7                   1               1   20161028
# 29              11   -89    65                   1               0   20161028
# ...            ...   ...   ...                 ...             ...        ...
# 1501            19   -47   188                   1               0   20170409
# 1502            24   173   178                   1               0   20170409
# 1503            25   -56   247                   1               0   20170409
# 1504             6    22    56                   1               1   20170409
# 1505            26   161   205                   1               1   20170409
# 1506            29    74   288                   1               0   20170409
# 1507            26   156   210                   1               1   20170409
# 1508             2   -17    16                   1               1   20170409
# 1509            25   -20   257                   1               0   20170410
# 1510            25    22   252                   1               0   20170410
# 1511            26    40   267                   1               0   20170410
# 1512             0     0     7                   1               1   20170410
# 1513            26  -138   228                   1               1   20170410
# 1514            56   166   540                   1               0   20170410
# 1515            28  -124   252                   1               0   20170410
# 1516            17   161    57                   1               0   20170410
# 1517             3     0    31                   1               0   20170410
# 1518             2   -19     7                   1               1   20170412
# 1519            24    -7   249                   1               0   20170412
# 1520            25  -176   188                   1               1   20170412
# 1521            25   212   136                   1               0   20170412
# 1522            24    10   242                   1               0   20170412
# 1523             1   -12     0                   1               1   20170412
# 1524             3   -19    26                   1               1   20170412
# 1525            25   186   169                   1               0   20170412
# 1526            24   225   100                   1               1   20170412
# 1527            22  -225   -10                   1               1   20170412
# 1528            25  -201   154                   1               1   20170412
# 1529            25  -199   154                   1               1   20170412
# 1530            25   161   198                   1               0   20170412
#
#       HTM  VTM
# 0     LAL  HOU
# 1     LAL  HOU
# 2     LAL  HOU
# 3     LAL  HOU
# 4     LAL  HOU
# 5     LAL  HOU
# 6     LAL  HOU
# 7     LAL  HOU
# 8     LAL  HOU
# 9     LAL  HOU
# 10    LAL  HOU
# 11    LAL  HOU
# 12    LAL  HOU
# 13    LAL  HOU
# 14    LAL  HOU
# 15    LAL  HOU
# 16    LAL  HOU
# 17    LAL  HOU
# 18    DAL  HOU
# 19    DAL  HOU
# 20    DAL  HOU
# 21    DAL  HOU
# 22    DAL  HOU
# 23    DAL  HOU
# 24    DAL  HOU
# 25    DAL  HOU
# 26    DAL  HOU
# 27    DAL  HOU
# 28    DAL  HOU
# 29    DAL  HOU
# ...   ...  ...
# 1501  SAC  HOU
# 1502  SAC  HOU
# 1503  SAC  HOU
# 1504  SAC  HOU
# 1505  SAC  HOU
# 1506  SAC  HOU
# 1507  SAC  HOU
# 1508  SAC  HOU
# 1509  LAC  HOU
# 1510  LAC  HOU
# 1511  LAC  HOU
# 1512  LAC  HOU
# 1513  LAC  HOU
# 1514  LAC  HOU
# 1515  LAC  HOU
# 1516  LAC  HOU
# 1517  LAC  HOU
# 1518  HOU  MIN
# 1519  HOU  MIN
# 1520  HOU  MIN
# 1521  HOU  MIN
# 1522  HOU  MIN
# 1523  HOU  MIN
# 1524  HOU  MIN
# 1525  HOU  MIN
# 1526  HOU  MIN
# 1527  HOU  MIN
# 1528  HOU  MIN
# 1529  HOU  MIN
# 1530  HOU  MIN
#
# [1531 rows x 24 columns]
